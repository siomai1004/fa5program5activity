# %% [markdown]
# <a href="https://colab.research.google.com/github/siomai1004/fa5program5activity/blob/main/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#function
def total_price(a, b):
   return a * b

#main
price = int(input("Enter price: "))
quantity = int(input("Enter number of items: "))
print("The total price is ", total_price(price, quantity))
# Out:
# Enter price: 50
# Enter number of items: 3
# The total price is  150
